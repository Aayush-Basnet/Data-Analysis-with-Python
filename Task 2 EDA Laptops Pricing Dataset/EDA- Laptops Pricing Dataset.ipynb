# %% [markdown]
# # Exploratory Data Analysis - Laptops Pricing dataset
#
# ### Objectives
#
#     - Visualize individual feature patterns
#     - Run descriptive statistical analysis on the dataset
#     - Use groups and pivot tables to find the effect of categorical variables on price
#     - Use Pearson Correlation to measure the interdependence between variables
#
#
#
#  ## Importing Required Libraires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Aayush\Documents\Python Learning\pandas-project\Data Analysis with python\Task 2 EDA Laptops Pricing Dataset\laptop_pricing_dataset_mod2.csv",header =0)
df
# Out:
#      Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0               0           0         Acer         4    2   1         5
# 1               1           1         Dell         3    1   1         3
# 2               2           2         Dell         3    1   1         7
# 3               3           3         Dell         4    2   1         5
# 4               4           4           HP         4    2   1         7
# ..            ...         ...          ...       ...  ...  ..       ...
# 233           233         233       Lenovo         4    2   1         7
# 234           234         234      Toshiba         3    2   1         5
# 235           235         235       Lenovo         4    2   1         5
# 236           236         236       Lenovo         3    3   1         5
# 237           237         237      Toshiba         3    2   1         5
#
#      Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# ...

# %% [markdown]
# # Task 1 - Visualize individual feature patterns
#
# #### Continouus valued features
# Generate regression plots for each of the parameters against "Price". Also print the value of correlation of each feature with "Price".

# %%
# CPU_frequency plot
sns.regplot(x='CPU_frequency',y='Price',data = df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
# Screen_Size_inch plot
sns.regplot(x='Screen_Size_inch',y='Price',data = df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
# Weight_pounds plot

sns.regplot(x='Weight_pounds',y='Price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 3974.15)

# %%
# Correlation values of the three attributes with Price

for corre in ['CPU_frequency','Screen_Size_inch','Weight_pounds']:
    print(f"Correlation of Price and {corre} is", df[[corre,"Price"]].corr())
# Out:
# Correlation of Price and CPU_frequency is                CPU_frequency     Price
# CPU_frequency       1.000000  0.366666
# Price               0.366666  1.000000
# Correlation of Price and Screen_Size_inch is                   Screen_Size_inch     Price
# Screen_Size_inch          1.000000 -0.110644
# Price                    -0.110644  1.000000
# Correlation of Price and Weight_pounds is                Weight_pounds     Price
# Weight_pounds       1.000000 -0.050312
# Price              -0.050312  1.000000

# %% [markdown]
# Interpretation: "CPU_frequency" has a 36% positive correlation with price of laptops. The other two parameters have weak correlation with price.

# %% [markdown]
# ## Categorical Features
#
# General Box plots for the different features that hold categorical values. These features would be 'Category', 'GPU', 'OS', 'CPU-core', 'RAM_GB', 'Storage_GB_SSD'

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0             0           0         Acer         4    2   1         5
# 1             1           1         Dell         3    1   1         3
# 2             2           2         Dell         3    1   1         7
# 3             3           3         Dell         4    2   1         5
# 4             4           4           HP         4    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0              14.0       0.551724       8             256        3.52800
# 1              15.6       0.689655       4             256        4.85100
# 2              15.6       0.931034       8             256        4.85100
# 3              13.3       0.551724       8             128        2.69010
# 4              15.6       0.620690       8             256        4.21155
#
#    Price Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %%
df[df['Category']==4].head(10)
# Out:
#     Unnamed: 0.1  Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  \
# 0              0           0         Acer         4    2   1         5
# 3              3           3         Dell         4    2   1         5
# 4              4           4           HP         4    2   1         7
# 13            13          13         Dell         4    2   1         5
# 16            16          16         Dell         4    1   1         7
# 18            18          18         Dell         4    2   1         5
# 20            20          20           HP         4    3   1         7
# 22            22          22         Dell         4    2   1         7
# 24            24          24         Asus         4    2   1         7
# 28            28          28           HP         4    3   1         7
#
#     Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0               14.0       0.551724       8             256        3.52800
# ...

# %%
# Category Box plot
sns.boxplot(x="Category",y="Price",data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Price'>

# %%
# GPU Box plot
sns.boxplot(x='GPU',y='Price',data = df)
# Out:
# <Axes: xlabel='GPU', ylabel='Price'>

# %%
# OS Box plot
sns.boxplot(x='OS',y='Price',data=df)
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
# CPU_core Box plot
sns.boxplot(x="CPU_core", y="Price", data=df)
# Out:
# <Axes: xlabel='CPU_core', ylabel='Price'>

# %%
# RAM_GB Box plot
sns.boxplot(x='RAM_GB',y='Price',data = df)
# Out:
# <Axes: xlabel='RAM_GB', ylabel='Price'>

# %% [markdown]
# # Task 2 - Descriptive Statistical Analysis

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Category         GPU          OS  \
# count    238.000000  238.000000  238.000000  238.000000  238.000000
# mean     118.500000  118.500000    3.205882    2.151261    1.058824
# std       68.848868   68.848868    0.776533    0.638282    0.235790
# min        0.000000    0.000000    1.000000    1.000000    1.000000
# 25%       59.250000   59.250000    3.000000    2.000000    1.000000
# 50%      118.500000  118.500000    3.000000    2.000000    1.000000
# 75%      177.750000  177.750000    4.000000    3.000000    1.000000
# max      237.000000  237.000000    5.000000    3.000000    2.000000
#
#          CPU_core  Screen_Size_inch  CPU_frequency      RAM_GB  \
# count  238.000000        238.000000     238.000000  238.000000
# mean     5.630252         14.688655       0.813822    7.882353
# std      1.241787          1.166045       0.141860    2.482603
# min      3.000000         12.000000       0.413793    4.000000
# ...

# %%
df.describe(include=['object'])
# Out:
#        Manufacturer Price-binned
# count           238          238
# unique           11            3
# top            Dell          Low
# freq             71          160

# %%
df['Manufacturer'].nunique()
# Out:
# 11

# %% [markdown]
# # Task 3 - Group By and Pivot Tables
#
# Group the parameters "GPU", 'CPU_core',and 'Price' to make a pivot table and visualize this connection using the pcolor plot.

# %%
group_name = df[['GPU','CPU_core','Price']]
group_name.head()
# Out:
#    GPU  CPU_core  Price
# 0    2         5    978
# 1    1         3    634
# 2    1         7    946
# 3    2         5   1244
# 4    2         7    837

# %%
group_test1 = group_name.groupby(['GPU','CPU_core'],as_index=False).mean()
group_test1
# Out:
#    GPU  CPU_core        Price
# 0    1         3   769.250000
# 1    1         5   998.500000
# 2    1         7  1167.941176
# 3    2         3   785.076923
# 4    2         5  1462.197674
# 5    2         7  1744.621622
# 6    3         3   784.000000
# 7    3         5  1220.680000
# 8    3         7  1945.097561

# %%
# Create the pivot table

group_ptable = group_test1.pivot(index='GPU',columns='CPU_core')
group_ptable
# Out:
#                Price
# CPU_core           3            5            7
# GPU
# 1         769.250000   998.500000  1167.941176
# 2         785.076923  1462.197674  1744.621622
# 3         784.000000  1220.680000  1945.097561

# %%
# Create the plot

fig,ax = plt.subplots()
im = ax.pcolor(group_ptable,cmap='RdBu')

# label names
row_labels = group_ptable.columns.levels[1]
col_labels = group_ptable.index

# move ticks and labels to the center
ax.set_xticks(np.arange(group_ptable.shape[1]) + 0.5, minor = False)
ax.set_yticks(np.arange(group_ptable.shape[0]) + 0.5, minor = False)

# insert labels
ax.set_xticklabels(row_labels, minor = False)
ax.set_yticklabels(col_labels, minor = False)

fig.colorbar(im)

# %% [markdown]
# # Task 4 - Pearson Correlation and p-values
#
# Use the scipy.stats.pearsonr() funciton to evaluate the Pearson Coefficient and the p-values for each parameter tested above. this will help to determine the parameters most likely to have a strong effect on the price of the laptops.

# %%
pearson_coeff, pvalue = stats.pearsonr(df['RAM_GB'],df['Price'])
print('The Pearson Correlation Coefficient for RAM_GB is ',pearson_coeff,'with a P-value is ',pvalue)
# Out:
# The Pearson Correlation Coefficient for RAM_GB is  0.5492972971857845 with a P-value is  3.681560628842711e-20

# %%
for param in ['RAM_GB','CPU_frequency','Storage_GB_SSD','Screen_Size_inch','Weight_pounds','CPU_core','OS','GPU','Category']:
    pearson_coef, p_value = stats.pearsonr(df[param],df['Price'])
    print(param)
    print("The Pearson Correlation Coefficient for ",param," is ",pearson_coef," with a P-value is ",p_value)
# Out:
# RAM_GB
# The Pearson Correlation Coefficient for  RAM_GB  is  0.5492972971857845  with a P-value is  3.681560628842711e-20
# CPU_frequency
# The Pearson Correlation Coefficient for  CPU_frequency  is  0.36666555892588626  with a P-value is  5.502463350713296e-09
# Storage_GB_SSD
# The Pearson Correlation Coefficient for  Storage_GB_SSD  is  0.2434207552181029  with a P-value is  0.00014898923191724174
# Screen_Size_inch
# The Pearson Correlation Coefficient for  Screen_Size_inch  is  -0.11064420817118291  with a P-value is  0.08853397846830666
# Weight_pounds
# The Pearson Correlation Coefficient for  Weight_pounds  is  -0.05031225837751554  with a P-value is  0.43976938534338944
# CPU_core
# The Pearson Correlation Coefficient for  CPU_core  is  0.4593977773355117  with a P-value is  7.912950127009034e-14
# OS
# The Pearson Correlation Coefficient for  OS  is  -0.22172980114827376  with a P-value is  0.0005696642559246749
# GPU
# ...

# %% [markdown]
# # Thank you for your time!!!
